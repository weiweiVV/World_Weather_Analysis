# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description=city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description}) 

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | high level
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | souillac
# Processing Record 7 of Set 1 | haimen
# Processing Record 8 of Set 1 | labuhan
# Processing Record 9 of Set 1 | saint-georges
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | provideniya
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | salalah
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | kiruna
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | burnie
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | lompoc
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | leningradskiy
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | puerto baquerizo moreno
# Processing Record 26 of Set 1 | cibitoke
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | dunedin
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | hofn
# Processing Record 31 of Set 1 | amapa
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | college
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | coquimbo
# Processing Record 36 of Set 1 | riosucio
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | yatou
# Processing Record 41 of Set 1 | chokurdakh
# Processing Record 42 of Set 1 | hirara
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | berbera
# Processing Record 45 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 1 | kloulklubed
# Processing Record 47 of Set 1 | mahebourg
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | hobart
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | pacific grove
# Processing Record 3 of Set 2 | kikwit
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | olafsvik
# Processing Record 6 of Set 2 | borogontsy
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | kizukuri
# Processing Record 9 of Set 2 | samarai
# Processing Record 10 of Set 2 | davila
# Processing Record 11 of Set 2 | numata
# Processing Record 12 of Set 2 | lebanon
# Processing Record 13 of Set 2 | fairbanks
# Processing Record 14 of Set 2 | oktyabrskoye
# Processing Record 15 of Set 2 | saint george
# Processing Record 16 of Set 2 | laela
# Processing Record 17 of Set 2 | maxixe
# Processing Record 18 of Set 2 | seddon
# Processing Record 19 of Set 2 | bundaberg
# Processing Record 20 of Set 2 | olavarria
# Processing Record 21 of Set 2 | bathsheba
# Processing Record 22 of Set 2 | saint-augustin
# Processing Record 23 of Set 2 | ayagoz
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | pisco
# Processing Record 26 of Set 2 | sola
# Processing Record 27 of Set 2 | llangefni
# Processing Record 28 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 2 | san quintin
# Processing Record 30 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 2 | wielun
# Processing Record 32 of Set 2 | miandrivazo
# Processing Record 33 of Set 2 | desdunes
# Processing Record 34 of Set 2 | chuy
# Processing Record 35 of Set 2 | faanui
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | bumba
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | clyde river
# Processing Record 41 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 2 | sakakah
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | airai
# Processing Record 45 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 2 | constitucion
# Processing Record 47 of Set 2 | half moon bay
# Processing Record 48 of Set 2 | sao gabriel da cachoeira
# Processing Record 49 of Set 2 | kaitangata
# Processing Record 50 of Set 2 | kushiro
# Processing Record 1 of Set 3 | zarubino
# Processing Record 2 of Set 3 | saint-junien
# Processing Record 3 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 3 | mercedes
# Processing Record 5 of Set 3 | aklavik
# Processing Record 6 of Set 3 | vuktyl
# Processing Record 7 of Set 3 | rockport
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | pangnirtung
# Processing Record 10 of Set 3 | tuktoyaktuk
# Processing Record 11 of Set 3 | torbay
# Processing Record 12 of Set 3 | erzin
# Processing Record 13 of Set 3 | kutum
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | makakilo city
# Processing Record 16 of Set 3 | narsaq
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | polunochnoye
# Processing Record 19 of Set 3 | el campo
# Processing Record 20 of Set 3 | conde
# Processing Record 21 of Set 3 | berlevag
# Processing Record 22 of Set 3 | semporna
# Processing Record 23 of Set 3 | khatanga
# Processing Record 24 of Set 3 | pajapan
# Processing Record 25 of Set 3 | ahipara
# Processing Record 26 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 27 of Set 3 | tessalit
# Processing Record 28 of Set 3 | rio de jesus
# Processing Record 29 of Set 3 | fredericksburg
# Processing Record 30 of Set 3 | yumen
# Processing Record 31 of Set 3 | kinanah
# City not found. Skipping...
# Processing Record 32 of Set 3 | takaungu
# Processing Record 33 of Set 3 | norman wells
# Processing Record 34 of Set 3 | albanel
# Processing Record 35 of Set 3 | skoropuskovskiy
# Processing Record 36 of Set 3 | burica
# City not found. Skipping...
# Processing Record 37 of Set 3 | hami
# Processing Record 38 of Set 3 | kuytun
# Processing Record 39 of Set 3 | madras
# Processing Record 40 of Set 3 | saskylakh
# Processing Record 41 of Set 3 | zweibrucken
# Processing Record 42 of Set 3 | westport
# Processing Record 43 of Set 3 | puga
# Processing Record 44 of Set 3 | qaqortoq
# Processing Record 45 of Set 3 | kologriv
# Processing Record 46 of Set 3 | katsuura
# Processing Record 47 of Set 3 | mpika
# Processing Record 48 of Set 3 | urulga
# City not found. Skipping...
# Processing Record 49 of Set 3 | pulandian
# Processing Record 50 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 4 | ovsyanka
# Processing Record 2 of Set 4 | tabou
# Processing Record 3 of Set 4 | vernon
# Processing Record 4 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 4 | jamestown
# Processing Record 8 of Set 4 | sao jose da coroa grande
# Processing Record 9 of Set 4 | varkkallai
# Processing Record 10 of Set 4 | esperance
# Processing Record 11 of Set 4 | rio gallegos
# Processing Record 12 of Set 4 | oranjemund
# Processing Record 13 of Set 4 | sydney mines
# Processing Record 14 of Set 4 | ilongero
# Processing Record 15 of Set 4 | breves
# Processing Record 16 of Set 4 | kapaa
# Processing Record 17 of Set 4 | tsienyane
# City not found. Skipping...
# Processing Record 18 of Set 4 | vaini
# Processing Record 19 of Set 4 | paamiut
# Processing Record 20 of Set 4 | kolondieba
# Processing Record 21 of Set 4 | notre-dame-du-lac
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | karratha
# Processing Record 24 of Set 4 | ekhabi
# Processing Record 25 of Set 4 | marystown
# Processing Record 26 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 4 | yellowknife
# Processing Record 28 of Set 4 | bambous virieux
# Processing Record 29 of Set 4 | huilong
# Processing Record 30 of Set 4 | san cristobal
# Processing Record 31 of Set 4 | henties bay
# Processing Record 32 of Set 4 | georgetown
# Processing Record 33 of Set 4 | dikson
# Processing Record 34 of Set 4 | krasnoselkup
# Processing Record 35 of Set 4 | nikolskoye
# Processing Record 36 of Set 4 | meulaboh
# Processing Record 37 of Set 4 | estelle
# Processing Record 38 of Set 4 | port keats
# Processing Record 39 of Set 4 | port blair
# Processing Record 40 of Set 4 | cape town
# Processing Record 41 of Set 4 | sabile
# Processing Record 42 of Set 4 | alekseyevsk
# Processing Record 43 of Set 4 | lexington
# Processing Record 44 of Set 4 | kavieng
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 4 | alyangula
# Processing Record 48 of Set 4 | upata
# Processing Record 49 of Set 4 | malmesbury
# Processing Record 50 of Set 4 | sangar
# Processing Record 1 of Set 5 | gizo
# Processing Record 2 of Set 5 | bairiki
# Processing Record 3 of Set 5 | bandarbeyla
# Processing Record 4 of Set 5 | khoy
# Processing Record 5 of Set 5 | port lincoln
# Processing Record 6 of Set 5 | kirakira
# Processing Record 7 of Set 5 | balsta
# Processing Record 8 of Set 5 | moose factory
# Processing Record 9 of Set 5 | corn island
# Processing Record 10 of Set 5 | roma
# Processing Record 11 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 5 | bethel
# Processing Record 13 of Set 5 | aktash
# Processing Record 14 of Set 5 | husavik
# Processing Record 15 of Set 5 | sao sebastiao
# Processing Record 16 of Set 5 | nhulunbuy
# Processing Record 17 of Set 5 | dolores
# Processing Record 18 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 19 of Set 5 | ovalle
# Processing Record 20 of Set 5 | cruzilia
# Processing Record 21 of Set 5 | hualmay
# Processing Record 22 of Set 5 | tigil
# Processing Record 23 of Set 5 | noumea
# Processing Record 24 of Set 5 | palana
# Processing Record 25 of Set 5 | sibolga
# Processing Record 26 of Set 5 | port-gentil
# Processing Record 27 of Set 5 | aklera
# Processing Record 28 of Set 5 | znamenskoye
# Processing Record 29 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 5 | crossville
# Processing Record 31 of Set 5 | tashigang
# Processing Record 32 of Set 5 | klaksvik
# Processing Record 33 of Set 5 | madang
# Processing Record 34 of Set 5 | misratah
# Processing Record 35 of Set 5 | mount gambier
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | los llanos de aridane
# Processing Record 38 of Set 5 | ca mau
# Processing Record 39 of Set 5 | voznesenye
# Processing Record 40 of Set 5 | altay
# Processing Record 41 of Set 5 | cherskiy
# Processing Record 42 of Set 5 | la asuncion
# Processing Record 43 of Set 5 | shagonar
# Processing Record 44 of Set 5 | pangai
# Processing Record 45 of Set 5 | lorengau
# Processing Record 46 of Set 5 | chicama
# Processing Record 47 of Set 5 | ottawa
# Processing Record 48 of Set 5 | fortuna
# Processing Record 49 of Set 5 | pevek
# Processing Record 50 of Set 5 | asau
# Processing Record 1 of Set 6 | coihaique
# Processing Record 2 of Set 6 | uyemskiy
# Processing Record 3 of Set 6 | zehdenick
# Processing Record 4 of Set 6 | tuatapere
# Processing Record 5 of Set 6 | belmonte
# Processing Record 6 of Set 6 | bubaque
# Processing Record 7 of Set 6 | rajampet
# Processing Record 8 of Set 6 | charters towers
# Processing Record 9 of Set 6 | fujin
# Processing Record 10 of Set 6 | rocha
# Processing Record 11 of Set 6 | padang
# Processing Record 12 of Set 6 | zhireken
# Processing Record 13 of Set 6 | flinders
# Processing Record 14 of Set 6 | constantine
# Processing Record 15 of Set 6 | fairburn
# Processing Record 16 of Set 6 | nabire
# Processing Record 17 of Set 6 | kaberamaido
# Processing Record 18 of Set 6 | carmen
# Processing Record 19 of Set 6 | kitimat
# Processing Record 20 of Set 6 | payo
# Processing Record 21 of Set 6 | la palma
# Processing Record 22 of Set 6 | srednekolymsk
# Processing Record 23 of Set 6 | kalmunai
# Processing Record 24 of Set 6 | sao joao da barra
# Processing Record 25 of Set 6 | hasaki
# Processing Record 26 of Set 6 | hervey bay
# Processing Record 27 of Set 6 | wattegama
# Processing Record 28 of Set 6 | ligayan
# Processing Record 29 of Set 6 | ketchikan
# Processing Record 30 of Set 6 | taoudenni
# Processing Record 31 of Set 6 | qaanaaq
# Processing Record 32 of Set 6 | tomatlan
# Processing Record 33 of Set 6 | saldanha
# Processing Record 34 of Set 6 | neepawa
# Processing Record 35 of Set 6 | peddapalli
# Processing Record 36 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 6 | savannakhet
# Processing Record 38 of Set 6 | margate
# Processing Record 39 of Set 6 | muros
# Processing Record 40 of Set 6 | mananjary
# Processing Record 41 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 42 of Set 6 | yakovlevka
# Processing Record 43 of Set 6 | itarema
# Processing Record 44 of Set 6 | pingliang
# Processing Record 45 of Set 6 | namatanai
# Processing Record 46 of Set 6 | popondetta
# Processing Record 47 of Set 6 | praia
# Processing Record 48 of Set 6 | umm jarr
# City not found. Skipping...
# Processing Record 49 of Set 6 | longyearbyen
# Processing Record 50 of Set 6 | pedernales
# Processing Record 1 of Set 7 | tasiilaq
# Processing Record 2 of Set 7 | along
# Processing Record 3 of Set 7 | nanortalik
# Processing Record 4 of Set 7 | yulara
# Processing Record 5 of Set 7 | carnarvon
# Processing Record 6 of Set 7 | novyy oskol
# Processing Record 7 of Set 7 | cidreira
# Processing Record 8 of Set 7 | shelburne
# Processing Record 9 of Set 7 | nizwa
# Processing Record 10 of Set 7 | ahuimanu
# Processing Record 11 of Set 7 | port macquarie
# Processing Record 12 of Set 7 | bonavista
# Processing Record 13 of Set 7 | fort nelson
# Processing Record 14 of Set 7 | batagay-alyta
# Processing Record 15 of Set 7 | pandan
# Processing Record 16 of Set 7 | onalaska
# Processing Record 17 of Set 7 | kaya
# Processing Record 18 of Set 7 | tateyama
# Processing Record 19 of Set 7 | severo-kurilsk
# Processing Record 20 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 21 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 7 | lander
# Processing Record 23 of Set 7 | bengkulu
# Processing Record 24 of Set 7 | hansot
# Processing Record 25 of Set 7 | egvekinot
# Processing Record 26 of Set 7 | chapais
# Processing Record 27 of Set 7 | sitka
# Processing Record 28 of Set 7 | nesbyen
# Processing Record 29 of Set 7 | buala
# Processing Record 30 of Set 7 | ust-tsilma
# Processing Record 31 of Set 7 | santa rosa
# Processing Record 32 of Set 7 | kumylzhenskaya
# Processing Record 33 of Set 7 | djibo
# Processing Record 34 of Set 7 | gulshat
# City not found. Skipping...
# Processing Record 35 of Set 7 | pochutla
# Processing Record 36 of Set 7 | kosh-agach
# Processing Record 37 of Set 7 | sinnamary
# Processing Record 38 of Set 7 | zhanaozen
# Processing Record 39 of Set 7 | jucas
# Processing Record 40 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 7 | roebourne
# Processing Record 42 of Set 7 | botshabelo
# Processing Record 43 of Set 7 | puerto del rosario
# Processing Record 44 of Set 7 | bilibino
# Processing Record 45 of Set 7 | tacuarembo
# Processing Record 46 of Set 7 | tabas
# Processing Record 47 of Set 7 | faya
# Processing Record 48 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 7 | lavrentiya
# Processing Record 50 of Set 7 | khomeyn
# Processing Record 1 of Set 8 | santa cruz del sur
# Processing Record 2 of Set 8 | banjar
# Processing Record 3 of Set 8 | abu samrah
# Processing Record 4 of Set 8 | caravelas
# Processing Record 5 of Set 8 | keetmanshoop
# Processing Record 6 of Set 8 | chipinge
# Processing Record 7 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 8 of Set 8 | zhaodong
# Processing Record 9 of Set 8 | kudal
# Processing Record 10 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 8 | inhambane
# Processing Record 12 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 13 of Set 8 | pizarro
# Processing Record 14 of Set 8 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 15 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 16 of Set 8 | lethem
# Processing Record 17 of Set 8 | tegal
# Processing Record 18 of Set 8 | portlethen
# Processing Record 19 of Set 8 | kavaratti
# Processing Record 20 of Set 8 | tashtagol
# Processing Record 21 of Set 8 | sao filipe
# Processing Record 22 of Set 8 | platteville
# Processing Record 23 of Set 8 | allapalli
# Processing Record 24 of Set 8 | beringovskiy
# Processing Record 25 of Set 8 | sao francisco
# Processing Record 26 of Set 8 | victoria
# Processing Record 27 of Set 8 | aksarka
# Processing Record 28 of Set 8 | vallenar
# Processing Record 29 of Set 8 | lazaro cardenas
# Processing Record 30 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 8 | napajedla
# Processing Record 32 of Set 8 | acapetahua
# Processing Record 33 of Set 8 | xicotencatl
# Processing Record 34 of Set 8 | newport
# Processing Record 35 of Set 8 | naze
# Processing Record 36 of Set 8 | xadani
# City not found. Skipping...
# Processing Record 37 of Set 8 | coro
# Processing Record 38 of Set 8 | toora-khem
# Processing Record 39 of Set 8 | colac
# Processing Record 40 of Set 8 | snasa
# Processing Record 41 of Set 8 | vermilion
# Processing Record 42 of Set 8 | sunrise manor
# Processing Record 43 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 44 of Set 8 | roald
# Processing Record 45 of Set 8 | ambulu
# Processing Record 46 of Set 8 | kot addu
# Processing Record 47 of Set 8 | codrington
# Processing Record 48 of Set 8 | nerchinskiy zavod
# Processing Record 49 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 8 | jacareacanga
# Processing Record 1 of Set 9 | leonidovo
# Processing Record 2 of Set 9 | quatre cocos
# Processing Record 3 of Set 9 | atasu
# Processing Record 4 of Set 9 | osinovo
# Processing Record 5 of Set 9 | havoysund
# Processing Record 6 of Set 9 | havre-saint-pierre
# Processing Record 7 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 9 | saint anthony
# Processing Record 9 of Set 9 | sawakin
# Processing Record 10 of Set 9 | ayan
# Processing Record 11 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 9 | xining
# Processing Record 13 of Set 9 | prince rupert
# Processing Record 14 of Set 9 | zambezi
# Processing Record 15 of Set 9 | bira
# Processing Record 16 of Set 9 | butterworth
# Processing Record 17 of Set 9 | kang
# Processing Record 18 of Set 9 | areka
# Processing Record 19 of Set 9 | unai
# Processing Record 20 of Set 9 | ust-nera
# Processing Record 21 of Set 9 | sorland
# Processing Record 22 of Set 9 | kurchum
# Processing Record 23 of Set 9 | viking
# Processing Record 24 of Set 9 | vaiusu
# Processing Record 25 of Set 9 | tambul
# City not found. Skipping...
# Processing Record 26 of Set 9 | eureka
# Processing Record 27 of Set 9 | pailon
# Processing Record 28 of Set 9 | kasongo-lunda
# Processing Record 29 of Set 9 | ngama
# Processing Record 30 of Set 9 | basna
# Processing Record 31 of Set 9 | dicabisagan
# Processing Record 32 of Set 9 | nusaybin
# Processing Record 33 of Set 9 | souris
# Processing Record 34 of Set 9 | biak
# Processing Record 35 of Set 9 | coahuayana
# Processing Record 36 of Set 9 | tirumullaivasal
# Processing Record 37 of Set 9 | mirnyy
# Processing Record 38 of Set 9 | dzaoudzi
# Processing Record 39 of Set 9 | auki
# Processing Record 40 of Set 9 | port augusta
# Processing Record 41 of Set 9 | cabo san lucas
# Processing Record 42 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 43 of Set 9 | jalu
# Processing Record 44 of Set 9 | redlands
# Processing Record 45 of Set 9 | namibe
# Processing Record 46 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 9 | robinson
# Processing Record 49 of Set 9 | luderitz
# Processing Record 50 of Set 9 | kaeo
# Processing Record 1 of Set 10 | vila franca do campo
# Processing Record 2 of Set 10 | ilanskiy
# Processing Record 3 of Set 10 | porbandar
# Processing Record 4 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 10 | bulzesti
# Processing Record 6 of Set 10 | aransas pass
# Processing Record 7 of Set 10 | aykhal
# Processing Record 8 of Set 10 | muisne
# Processing Record 9 of Set 10 | manavalakurichi
# Processing Record 10 of Set 10 | fougamou
# Processing Record 11 of Set 10 | harlingen
# Processing Record 12 of Set 10 | zapolyarnyy
# Processing Record 13 of Set 10 | bastia
# Processing Record 14 of Set 10 | hamilton
# Processing Record 15 of Set 10 | kiama
# Processing Record 16 of Set 10 | flin flon
# Processing Record 17 of Set 10 | udachnyy
# Processing Record 18 of Set 10 | luanda
# Processing Record 19 of Set 10 | bermejo
# Processing Record 20 of Set 10 | ponta delgada
# Processing Record 21 of Set 10 | aquitania
# Processing Record 22 of Set 10 | suluova
# Processing Record 23 of Set 10 | bam
# Processing Record 24 of Set 10 | palatka
# Processing Record 25 of Set 10 | coffs harbour
# Processing Record 26 of Set 10 | sioux lookout
# Processing Record 27 of Set 10 | avera
# Processing Record 28 of Set 10 | yagoua
# Processing Record 29 of Set 10 | indija
# Processing Record 30 of Set 10 | strathmore
# Processing Record 31 of Set 10 | isangel
# Processing Record 32 of Set 10 | kano
# Processing Record 33 of Set 10 | ancud
# Processing Record 34 of Set 10 | atyrau
# Processing Record 35 of Set 10 | llanes
# Processing Record 36 of Set 10 | monroe
# Processing Record 37 of Set 10 | san policarpo
# Processing Record 38 of Set 10 | hambantota
# Processing Record 39 of Set 10 | yar-sale
# Processing Record 40 of Set 10 | semnan
# Processing Record 41 of Set 10 | san juan
# Processing Record 42 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 43 of Set 10 | talnakh
# Processing Record 44 of Set 10 | muhos
# Processing Record 45 of Set 10 | beyneu
# Processing Record 46 of Set 10 | yakeshi
# Processing Record 47 of Set 10 | san ramon
# Processing Record 48 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 10 | chumikan
# Processing Record 50 of Set 10 | sangueya
# Processing Record 1 of Set 11 | taranagar
# Processing Record 2 of Set 11 | bria
# Processing Record 3 of Set 11 | laguna
# Processing Record 4 of Set 11 | balkanabat
# Processing Record 5 of Set 11 | nizhniy kuranakh
# Processing Record 6 of Set 11 | mattawa
# Processing Record 7 of Set 11 | shirvan
# Processing Record 8 of Set 11 | sur
# Processing Record 9 of Set 11 | kathmandu
# Processing Record 10 of Set 11 | te anau
# Processing Record 11 of Set 11 | jutai
# Processing Record 12 of Set 11 | saiha
# Processing Record 13 of Set 11 | zarinsk
# Processing Record 14 of Set 11 | abha
# Processing Record 15 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 11 | alofi
# Processing Record 17 of Set 11 | homer
# Processing Record 18 of Set 11 | meridian
# Processing Record 19 of Set 11 | tiarei
# Processing Record 20 of Set 11 | halifax
# Processing Record 21 of Set 11 | sisimiut
# Processing Record 22 of Set 11 | zhigalovo
# Processing Record 23 of Set 11 | paracuru
# Processing Record 24 of Set 11 | imphal
# Processing Record 25 of Set 11 | great falls
# Processing Record 26 of Set 11 | cockburn town
# Processing Record 27 of Set 11 | daule
# Processing Record 28 of Set 11 | dodola
# Processing Record 29 of Set 11 | konstanz
# Processing Record 30 of Set 11 | aripuana
# Processing Record 31 of Set 11 | stillwater
# Processing Record 32 of Set 11 | strezhevoy
# Processing Record 33 of Set 11 | sturgeon bay
# Processing Record 34 of Set 11 | lufilufi
# Processing Record 35 of Set 11 | qasigiannguit
# Processing Record 36 of Set 11 | vanimo
# Processing Record 37 of Set 11 | fairlie
# Processing Record 38 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 11 | dudinka
# Processing Record 40 of Set 11 | tvoroyri
# Processing Record 41 of Set 11 | tocopilla
# Processing Record 42 of Set 11 | xique-xique
# Processing Record 43 of Set 11 | mindelo
# Processing Record 44 of Set 11 | san patricio
# Processing Record 45 of Set 11 | amboasary
# Processing Record 46 of Set 11 | zyryanka
# Processing Record 47 of Set 11 | channarayapatna
# Processing Record 48 of Set 11 | wanning
# Processing Record 49 of Set 11 | neiafu
# Processing Record 50 of Set 11 | ribeira grande
# Processing Record 1 of Set 12 | mweka
# Processing Record 2 of Set 12 | okhotsk
# Processing Record 3 of Set 12 | sagua la grande
# Processing Record 4 of Set 12 | talara
# Processing Record 5 of Set 12 | staryy nadym
# Processing Record 6 of Set 12 | saint-pierre
# Processing Record 7 of Set 12 | maunabo
# Processing Record 8 of Set 12 | waipawa
# Processing Record 9 of Set 12 | joshimath
# Processing Record 10 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 12 | tommot
# Processing Record 12 of Set 12 | oakdale
# Processing Record 13 of Set 12 | bereda
# Processing Record 14 of Set 12 | mackenzie
# Processing Record 15 of Set 12 | zhigansk
# Processing Record 16 of Set 12 | esil
# Processing Record 17 of Set 12 | sistranda
# Processing Record 18 of Set 12 | austin
# Processing Record 19 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 12 | mattru
# Processing Record 21 of Set 12 | karaton
# Processing Record 22 of Set 12 | gdov
# Processing Record 23 of Set 12 | vardo
# Processing Record 24 of Set 12 | nouadhibou
# Processing Record 25 of Set 12 | iskateley
# Processing Record 26 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 27 of Set 12 | zhuhai
# Processing Record 28 of Set 12 | vestmannaeyjar
# Processing Record 29 of Set 12 | oum hadjer
# Processing Record 30 of Set 12 | mayo
# Processing Record 31 of Set 12 | boshnyakovo
# Processing Record 32 of Set 12 | domna
# Processing Record 33 of Set 12 | mongar
# Processing Record 34 of Set 12 | akureyri
# Processing Record 35 of Set 12 | mareeba
# Processing Record 36 of Set 12 | tunis
# Processing Record 37 of Set 12 | the valley
# Processing Record 38 of Set 12 | guiratinga
# Processing Record 39 of Set 12 | bolshiye uki
# City not found. Skipping...
# Processing Record 40 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 12 | tambovka
# Processing Record 42 of Set 12 | maracaibo
# Processing Record 43 of Set 12 | bandrele
# Processing Record 44 of Set 12 | vao
# Processing Record 45 of Set 12 | tempio pausania
# Processing Record 46 of Set 12 | davidson
# Processing Record 47 of Set 12 | honiara
# Processing Record 48 of Set 12 | cap malheureux
# Processing Record 49 of Set 12 | artesia
# Processing Record 50 of Set 12 | magadan
# Processing Record 1 of Set 13 | la macarena
# Processing Record 2 of Set 13 | waingapu
# Processing Record 3 of Set 13 | lekoni
# Processing Record 4 of Set 13 | tefe
# Processing Record 5 of Set 13 | normandin
# Processing Record 6 of Set 13 | fantino
# Processing Record 7 of Set 13 | porto velho
# Processing Record 8 of Set 13 | abbeville
# Processing Record 9 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 13 | tevriz
# Processing Record 11 of Set 13 | kargasok
# Processing Record 12 of Set 13 | shimoda
# Processing Record 13 of Set 13 | trairi
# Processing Record 14 of Set 13 | bilma
# Processing Record 15 of Set 13 | puerto escondido
# Processing Record 16 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 17 of Set 13 | chipoka
# Processing Record 18 of Set 13 | chokwe
# Processing Record 19 of Set 13 | mincivan
# Processing Record 20 of Set 13 | byron bay
# Processing Record 21 of Set 13 | malanje
# Processing Record 22 of Set 13 | svetlyy
# Processing Record 23 of Set 13 | lima
# Processing Record 24 of Set 13 | tarakan
# Processing Record 25 of Set 13 | fonte boa
# Processing Record 26 of Set 13 | silva jardim
# Processing Record 27 of Set 13 | marrakesh
# Processing Record 28 of Set 13 | batemans bay
# Processing Record 29 of Set 13 | choya
# Processing Record 30 of Set 13 | charlestown
# Processing Record 31 of Set 13 | rorvik
# Processing Record 32 of Set 13 | ilorin
# Processing Record 33 of Set 13 | robertsport
# Processing Record 34 of Set 13 | bambanglipuro
# Processing Record 35 of Set 13 | comodoro rivadavia
# Processing Record 36 of Set 13 | vila
# Processing Record 37 of Set 13 | powell river
# Processing Record 38 of Set 13 | uruzgan
# Processing Record 39 of Set 13 | olinda
# Processing Record 40 of Set 13 | kuusamo
# Processing Record 41 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 13 | vostok
# Processing Record 43 of Set 13 | poum
# Processing Record 44 of Set 13 | latung
# Processing Record 45 of Set 13 | yeltsovka
# City not found. Skipping...
# Processing Record 46 of Set 13 | kailua
# Processing Record 47 of Set 13 | daguma
# Processing Record 48 of Set 13 | mwense
# Processing Record 49 of Set 13 | puerto carreno
# Processing Record 50 of Set 13 | praia da vitoria
# Processing Record 1 of Set 14 | steamboat springs
# Processing Record 2 of Set 14 | kudahuvadhoo
# Processing Record 3 of Set 14 | duz
# City not found. Skipping...
# Processing Record 4 of Set 14 | salaga
# Processing Record 5 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 6 of Set 14 | sosnovo-ozerskoye
# Processing Record 7 of Set 14 | sayyan
# Processing Record 8 of Set 14 | brazzaville
# Processing Record 9 of Set 14 | alvinopolis
# Processing Record 10 of Set 14 | kawalu
# Processing Record 11 of Set 14 | belyy yar
# Processing Record 12 of Set 14 | north platte
# Processing Record 13 of Set 14 | katiola
# Processing Record 14 of Set 14 | raudeberg
# Processing Record 15 of Set 14 | hare bay
# Processing Record 16 of Set 14 | vila velha
# Processing Record 17 of Set 14 | ituango
# Processing Record 18 of Set 14 | mapastepec
# Processing Record 19 of Set 14 | dingle
# Processing Record 20 of Set 14 | cayenne
# Processing Record 21 of Set 14 | sibu
# Processing Record 22 of Set 14 | kununurra
# Processing Record 23 of Set 14 | aguimes
# Processing Record 24 of Set 14 | camopi
# Processing Record 25 of Set 14 | uenohara
# Processing Record 26 of Set 14 | palu
# Processing Record 27 of Set 14 | may pen
# Processing Record 28 of Set 14 | teloloapan
# Processing Record 29 of Set 14 | vastervik
# City not found. Skipping...
# Processing Record 30 of Set 14 | deep river
# Processing Record 31 of Set 14 | diego de almagro
# Processing Record 32 of Set 14 | shirokiy
# Processing Record 33 of Set 14 | machali
# Processing Record 34 of Set 14 | terney
# Processing Record 35 of Set 14 | huarmey
# Processing Record 36 of Set 14 | new ulm
# Processing Record 37 of Set 14 | ndele
# Processing Record 38 of Set 14 | umbertide
# Processing Record 39 of Set 14 | pierre
# Processing Record 40 of Set 14 | araouane
# Processing Record 41 of Set 14 | sabang
# Processing Record 42 of Set 14 | camana
# Processing Record 43 of Set 14 | tilichiki
# Processing Record 44 of Set 14 | balimo
# City not found. Skipping...
# Processing Record 45 of Set 14 | alice springs
# Processing Record 46 of Set 14 | lamu
# Processing Record 47 of Set 14 | ust-maya
# Processing Record 48 of Set 14 | san jeronimo
# Processing Record 49 of Set 14 | takestan
# Processing Record 50 of Set 14 | palembang
# Processing Record 1 of Set 15 | adrar
# Processing Record 2 of Set 15 | newark
# Processing Record 3 of Set 15 | tura
# Processing Record 4 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 15 | veroia
# Processing Record 6 of Set 15 | ixtapa
# Processing Record 7 of Set 15 | kruisfontein
# Processing Record 8 of Set 15 | arinos
# Processing Record 9 of Set 15 | havelock
# Processing Record 10 of Set 15 | ust-kulom
# Processing Record 11 of Set 15 | kochi
# Processing Record 12 of Set 15 | matai
# Processing Record 13 of Set 15 | marsh harbour
# Processing Record 14 of Set 15 | nuuk
# Processing Record 15 of Set 15 | loandjili
# Processing Record 16 of Set 15 | marathon
# Processing Record 17 of Set 15 | liverpool
# Processing Record 18 of Set 15 | xghajra
# City not found. Skipping...
# Processing Record 19 of Set 15 | sebrovo
# Processing Record 20 of Set 15 | soyo
# Processing Record 21 of Set 15 | lusambo
# Processing Record 22 of Set 15 | elwood
# Processing Record 23 of Set 15 | goderich
# Processing Record 24 of Set 15 | san anselmo
# Processing Record 25 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 26 of Set 15 | mineiros
# Processing Record 27 of Set 15 | pringsewu
# Processing Record 28 of Set 15 | grand-santi
# Processing Record 29 of Set 15 | kyra
# Processing Record 30 of Set 15 | temir
# Processing Record 31 of Set 15 | ocos
# Processing Record 32 of Set 15 | playa vicente
# Processing Record 33 of Set 15 | gimli
# Processing Record 34 of Set 15 | port hedland
# Processing Record 35 of Set 15 | thinadhoo
# Processing Record 36 of Set 15 | axim
# Processing Record 37 of Set 15 | khorramshahr
# Processing Record 38 of Set 15 | kyabe
# Processing Record 39 of Set 15 | asfi
# Processing Record 40 of Set 15 | oktyabrskiy
# Processing Record 41 of Set 15 | meadow lake
# Processing Record 42 of Set 15 | nelson bay
# Processing Record 43 of Set 15 | mirabad
# Processing Record 44 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 45 of Set 15 | mezhgorye
# Processing Record 46 of Set 15 | sargatskoye
# Processing Record 47 of Set 15 | maniitsoq
# Processing Record 48 of Set 15 | cairns
# Processing Record 49 of Set 15 | brewster
# Processing Record 50 of Set 15 | fallon
# Processing Record 1 of Set 16 | ishigaki
# Processing Record 2 of Set 16 | tranas
# Processing Record 3 of Set 16 | keelung
# Processing Record 4 of Set 16 | shakhtinsk
# Processing Record 5 of Set 16 | korla
# Processing Record 6 of Set 16 | sinegorye
# Processing Record 7 of Set 16 | kahului
# Processing Record 8 of Set 16 | burkhala
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     High Level  58.5169 -117.1360     26.60        43          20
# 1     Butaritari   3.0707  172.7902     81.77        80          55
# 2      Busselton -33.6500  115.3333     66.99        58           0
# 3      Hithadhoo  -0.6000   73.0833     82.36        67          12
# 4           Hilo  19.7297 -155.0900     71.60        73          90
# 5       Souillac -20.5167   57.5167     78.80        73          40
# 6         Haimen  23.1935  116.6142     64.40        77          90
# 7        Labuhan  -6.8844  112.2051     84.56        73          88
# 8  Saint-Georges  12.0564  -61.7485     78.80        83          20
# 9        Mataura -46.1927  168.8643     67.24        39           0
#
#    Wind Speed Country Current Description
# 0        6.91      CA          few clouds
# 1       15.79      KI          light rain
# 2        3.00      AU           clear sky
# 3       10.74      MV          few clouds
# 4        8.05      US          light rain
# 5        6.91      MU    scattered clouds
# 6        4.47      CN          light rain
# 7        7.18      ID     overcast clouds
# 8       10.36      GD          few clouds
# 9        1.61      NZ           clear sky

# %%
new_column_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     High Level      CA  58.5169 -117.1360     26.60        43          20
# 1     Butaritari      KI   3.0707  172.7902     81.77        80          55
# 2      Busselton      AU -33.6500  115.3333     66.99        58           0
# 3      Hithadhoo      MV  -0.6000   73.0833     82.36        67          12
# 4           Hilo      US  19.7297 -155.0900     71.60        73          90
# 5       Souillac      MU -20.5167   57.5167     78.80        73          40
# 6         Haimen      CN  23.1935  116.6142     64.40        77          90
# 7        Labuhan      ID  -6.8844  112.2051     84.56        73          88
# 8  Saint-Georges      GD  12.0564  -61.7485     78.80        83          20
# 9        Mataura      NZ -46.1927  168.8643     67.24        39           0
#
#    Wind Speed Current Description
# 0        6.91          few clouds
# 1       15.79          light rain
# 2        3.00           clear sky
# 3       10.74          few clouds
# 4        8.05          light rain
# 5        6.91    scattered clouds
# 6        4.47          light rain
# 7        7.18     overcast clouds
# 8       10.36          few clouds
# 9        1.61           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
